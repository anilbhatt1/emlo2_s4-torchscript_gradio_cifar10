# %%
# !git clone https://github.com/anilbhatt1/emlo2_s4-torchscript_gradio_cifar10.git
# Out:
# Cloning into 'emlo2_s4-torchscript_gradio_cifar10'...
# remote: Enumerating objects: 307, done.
# remote: Counting objects: 100% (307/307), done.
# remote: Compressing objects: 100% (221/221), done.
# remote: Total 307 (delta 152), reused 231 (delta 77), pack-reused 0
# Receiving objects: 100% (307/307), 78.05 KiB | 1.77 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %%
import os
os.chdir('/content/emlo2_s4-torchscript_gradio_cifar10')
print('Current work dir:', os.getcwd())
# Out:
# Current work dir: /content/emlo2_s4-torchscript_gradio_cifar10

# %%
# !pip install -r './requirements.txt' -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.8/764.8 kB 56.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 73.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 30.9 MB/s eta 0:00:00
# ...

# %%
# !python3 src/train.py experiment=cifar_timm
# Out:
# [2023-09-18 08:36:33,557][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2023-09-18 08:36:33,563][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── data
# │   └── _target_: src.data.cifar_datamodule.CIFAR10DataModule
# │       data_dir: /content/emlo2_s4-torchscript_gradio_cifar10/data/
# │       batch_size: 128
# │       train_val_test_split:
# │       - 45000
# │       - 5000
# │       - 10000
# │       num_workers: 0
# │       pin_memory: false
# │
# ├── model
# │   └── _target_: src.models.cifar10_module.CifarLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.001
# │         weight_decay: 0.0
# │       net:
# │         _target_: timm.create_model
# │         model_name: resnet18
# │         pretrained: true
# │         num_classes: 10
# │
# ├── callbacks
# │   └── model_checkpoint:
# ...

# %%
# !python3 src/demo_scripted.py ckpt_path='/content/emlo2_s4-torchscript_gradio_cifar10/logs/train/runs/2023-09-18_05-49-30/model.script.pt'
# Out:
# [2023-09-18 05:55:19,077][__main__][INFO] - Running Demo
# [2023-09-18 05:55:19,078][__main__][INFO] - Instantiating scripted model </content/emlo2_s4-torchscript_gradio_cifar10/logs/train/runs/2023-09-18_05-49-30/model.script.pt>
# [2023-09-18 05:55:19,308][__main__][INFO] - Loaded Model
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://41385c706a9823a52b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# /content/emlo2_s4-torchscript_gradio_cifar10/src/demo_scripted.py:42: UserWarning: operator() profile_node %913 : bool = prim::profile_ivalue(%training.1)
#  does not have profile information (Triggered internally at ../third_party/nvfuser/csrc/graph_fuser.cpp:104.)
#   preds = model.forward_jit(image)
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
# ...
